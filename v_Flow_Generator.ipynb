# %% [markdown]
# # Flow Generator
# Similar to the Image Generator notebook, we'll use this notebook to streamline the process of generating NetCDF files that contain the two variables **flow_u** and **flow_v**.

# %% [markdown]
# ## Importing necessary libraries and notebooks

# %%
import xarray as xr
import io
import os
import cv2
import imageio
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import netCDF4 as nc
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from datetime import datetime, timedelta
from matplotlib import ticker
from matplotlib.lines import Line2D
from matplotlib.patches import FancyArrowPatch
from matplotlib.collections import LineCollection
from IPython.display import Image, display, clear_output
from PIL import Image as PILImage
from concurrent.futures import ProcessPoolExecutor

from iv_Flow_NetCDF import *

# %% [markdown]
# ## DeepFlow

# %% [markdown]
# ### *process_file_pair*
# Function to parallelize the process of calculating the flow over the different pairs of images.
#
# **Crashes when run in parallel (no longer when limiting the max_workers).**

# %%
def process_file_pair(file_paths, destination_directory):
    first_path, second_path = file_paths
    # Calculate flow vectors for different variables
    flow_vectors = calculate_deepflow(first_path, second_path, variable_key="fai_anomaly")
    flow_vectors_f = calculate_deepflow(first_path, second_path, variable_key="filtered")

    # Define the output filename and path
    first_file = os.path.basename(first_path)
    output_filename = 'DeepFlow_' + first_file
    output_path = os.path.join(destination_directory, output_filename)

    # Save flow data
    save_flow(first_path, output_path, lat_range=None, lon_range=None, flow_vectors=flow_vectors, flow_vectors_m=None, flow_vectors_f=flow_vectors_f, mask_data=False)
    print(f"Processed and saved flow data for {first_file} to {output_filename}")
    return output_filename  # Return something to signify completion

# %%
if __name__ == '__main__':
    # Paths
    source_directory = '/media/yahia/ballena/ABI/NetCDF/Atlantic/Filtered'
    destination_directory = '/media/yahia/ballena/Flow/DeepFlow'

    # Ensure the destination directory exists
    os.makedirs(destination_directory, exist_ok=True)

    # Get all .nc files sorted to ensure chronological order
    files = sorted([f for f in os.listdir(source_directory) if f.endswith('.nc')])

    # Prepare pairs of files for processing
    file_pairs = [(os.path.join(source_directory, files[i]), os.path.join(source_directory, files[i+1])) for i in range(len(files) - 1)]

    # Adjust the number of max_workers based on your system capabilities
    max_workers = os.cpu_count() // 2  # For example, use half of your CPU cores

    # Use ProcessPoolExecutor to execute multiple processes
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        # Map the helper function to each pair of files
        futures = [executor.submit(process_file_pair, pair, destination_directory) for pair in file_pairs]

        # Optionally handle results as they complete
        for future in futures:
            try:
                print(future.result())  # Accessing result() will wait for the process to complete
            except Exception as e:
                print(f"Error processing file: {e}")

# %% [markdown]
# ## DeepFlow (Masked)

# %% [markdown]
# ### *mask_flow*
# This takes in the images for which flow is already calculated and sets flow to 0 in pixels where there is no algae detection.

# %%
def mask_flow(data, output_path):
    mask = data['fai_anomaly'] != 0
    for var in data.data_vars:
        # Check if there are filtered flow variables
        if ('flow_u_f' in var) or ('flow_v_f' in var):
            mask_filtered = data['filtered'] != 0
            data[var] = xr.where(mask_filtered, data[var], 0)
        if 'flow' in var:
            data[var] = xr.where(mask, data[var], 0)
    # Save the modified dataset to a new NetCDF file
    data.to_netcdf(output_path)

# %% [markdown]
# ### *mask_file*

# %%
def mask_file(file_path, destination_directory):
    """
    Load a dataset, apply masking, and save the modified dataset.
    """
    output_path = os.path.join(destination_directory, 'Masked_' + os.path.basename(file_path))
    data = xr.open_dataset(file_path)
    mask_flow(data, output_path)
    return f"Masked flow data for {os.path.basename(file_path)} to {output_path}"

# %%
if __name__ == '__main__':
    source_directory = '/media/yahia/ballena/Flow/DeepFlow'
    destination_directory = '/media/yahia/ballena/Flow/DeepFlow_Masked'

    # Ensure the destination directory exists
    os.makedirs(destination_directory, exist_ok=True)

    # Get all .nc files in the source directory
    filenames = [os.path.join(source_directory, f) for f in os.listdir(source_directory) if f.endswith('.nc')]

    # Use ProcessPoolExecutor to process files in parallel
    with ProcessPoolExecutor(max_workers=os.cpu_count()) as executor:
        # Map the processing function to each file
        results = executor.map(mask_file, filenames, [destination_directory]*len(filenames))

        # Optionally collect results or handle exceptions
        for result in results:
            print(result)
# Out:
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220701.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220701.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220704.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220704.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220703.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220703.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220702.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220702.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220705.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220705.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220706.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220706.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220708.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220708.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220707.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220707.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220709.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220709.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220710.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220710.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220713.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220713.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220712.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220712.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220714.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220714.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220716.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220716.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220718.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220718.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220717.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220717.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220720.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220720.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220719.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220719.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220722.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220722.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220721.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220721.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220725.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220725.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220724.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220724.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220723.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220723.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220726.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220726.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220504.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220504.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220501.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220501.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220503.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220503.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220502.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220502.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220505.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220505.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220506.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220506.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220507.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220507.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220508.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220508.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220509.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220509.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220510.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220510.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220511.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220511.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220512.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220512.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220515.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220515.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220513.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220513.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220516.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220516.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220517.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220517.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220518.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220518.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220519.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220519.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220520.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220520.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220521.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220521.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220523.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220523.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220522.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220522.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220524.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220524.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220525.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220525.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220526.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220526.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220527.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220527.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220528.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220528.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220529.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220529.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220530.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220530.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220601.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220601.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220602.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220602.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220603.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220603.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220604.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220604.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220605.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220605.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220606.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220606.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220607.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220607.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220608.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220608.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220609.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220609.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220610.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220610.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220611.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220611.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220612.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220612.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220613.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220613.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220614.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220614.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220615.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220615.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220616.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220616.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220619.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220619.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220620.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220620.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220621.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220621.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220622.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220622.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220623.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220623.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220624.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220624.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220625.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220625.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220626.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220626.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220627.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220627.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220628.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220628.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220629.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220629.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220630.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220630.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220727.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220727.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220728.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220728.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220729.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220729.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220730.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220730.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220731.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220731.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220801.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220801.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220802.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220802.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220803.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220803.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220805.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220805.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220804.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220804.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220806.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220806.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220807.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220807.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220808.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220808.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220809.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220809.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220810.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220810.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220817.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220817.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220818.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220818.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220819.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220819.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220820.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220820.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220821.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220821.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220822.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220822.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220823.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220823.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220824.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220824.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220825.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220825.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220826.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220826.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220827.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220827.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220828.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220828.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220829.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220829.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220830.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220830.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220831.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220831.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220901.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220901.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220902.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220902.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220904.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220904.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220903.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220903.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220905.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220905.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220906.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220906.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220908.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220908.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220907.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220907.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220909.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220909.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220910.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220910.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220913.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220913.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220912.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220912.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220914.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220914.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220915.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220915.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220916.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220916.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220917.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220917.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220918.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220918.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220919.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220919.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220920.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220920.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220921.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220921.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220922.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220922.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220923.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220923.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220925.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220925.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220924.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220924.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220926.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220926.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220927.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220927.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220928.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220928.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20220930.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20220930.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221001.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221001.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221002.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221002.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221003.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221003.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221004.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221004.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221005.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221005.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221006.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221006.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221007.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221007.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221008.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221008.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221009.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221009.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221010.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221010.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221011.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221011.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221012.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221012.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221013.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221013.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221014.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221014.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221015.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221015.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221016.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221016.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221017.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221017.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221018.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221018.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221019.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221019.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221020.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221020.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221021.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221021.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221022.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221022.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221023.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221023.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221024.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221024.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221025.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221025.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221026.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221026.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221027.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221027.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221028.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221028.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221029.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221029.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221030.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221030.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221031.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221031.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221101.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221101.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221103.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221103.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221104.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221104.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221106.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221106.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221105.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221105.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221107.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221107.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221108.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221108.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221110.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221110.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221109.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221109.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221111.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221111.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221112.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221112.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221113.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221113.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221114.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221114.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221115.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221115.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221116.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221116.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221117.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221117.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221118.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221118.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221119.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221119.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221121.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221121.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221122.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221122.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221123.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221123.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221124.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221124.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221125.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221125.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221126.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221126.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221127.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221127.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221128.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221128.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221129.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221129.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221130.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221130.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221201.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221201.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221202.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221202.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221203.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221203.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221207.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221207.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221204.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221204.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221208.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221208.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221209.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221209.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221210.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221210.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221211.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221211.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221212.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221212.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221213.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221213.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221215.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221215.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221214.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221214.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221216.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221216.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221217.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221217.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221218.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221218.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221219.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221219.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221220.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221220.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221221.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221221.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221222.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221222.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221223.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221223.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221224.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221224.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221225.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221225.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221226.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221226.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221227.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221227.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221228.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221228.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221229.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221229.nc
# Masked flow data for DeepFlow_Filtered_algae_distribution_20221230.nc to /media/yahia/ballena/Flow/DeepFlow_Masked/Masked_DeepFlow_Filtered_algae_distribution_20221230.nc

# %% [markdown]
# ## Farneback
# This is much faster than DeepFlow.

# %% [markdown]
# ### *process_file_pair_farneback*

# %%
def process_file_pair_farneback(file_paths, destination_directory):
    first_path, second_path = file_paths
    # Calculate flow vectors for different variables
    flow_vectors = calculate_farneback(first_path, second_path, variable_key="fai_anomaly")
    flow_vectors_f = calculate_farneback(first_path, second_path, variable_key="filtered")

    # Define the output filename and path
    first_file = os.path.basename(first_path)
    output_filename = 'Farneback_' + first_file
    output_path = os.path.join(destination_directory, output_filename)

    # Save flow data
    save_flow(first_path, output_path, lat_range=None, lon_range=None, flow_vectors=flow_vectors, flow_vectors_m=None, flow_vectors_f=flow_vectors_f, mask_data=False)
    print(f"Processed and saved flow data for {first_file} to {output_filename}")
    return output_filename  # Return something to signify completion

# %%
if __name__ == '__main__':
    # Paths
    source_directory = '/media/yahia/ballena/ABI/NetCDF/Atlantic/Filtered'
    destination_directory = '/media/yahia/ballena/Flow/Farneback'

    # Ensure the destination directory exists
    os.makedirs(destination_directory, exist_ok=True)

    # Get all .nc files sorted to ensure chronological order
    files = sorted([f for f in os.listdir(source_directory) if f.endswith('.nc')])

    # Prepare pairs of files for processing
    file_pairs = [(os.path.join(source_directory, files[i]), os.path.join(source_directory, files[i+1])) for i in range(len(files) - 1)]

    # Adjust the number of max_workers based on your system capabilities
    max_workers = os.cpu_count() // 2  # For example, use half of your CPU cores

    # Use ProcessPoolExecutor to execute multiple processes
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        # Map the helper function to each pair of files
        futures = [executor.submit(process_file_pair_farneback, pair, destination_directory) for pair in file_pairs]

        # Optionally handle results as they complete
        for future in futures:
            try:
                print(future.result())  # Accessing result() will wait for the process to complete
            except Exception as e:
                print(f"Error processing file: {e}")

# %% [markdown]
# ## Farneback (Masked)

# %%
if __name__ == '__main__':
    source_directory = '/media/yahia/ballena/Flow/Farneback'
    destination_directory = '/media/yahia/ballena/Flow/Farneback_Masked'

    # Ensure the destination directory exists
    os.makedirs(destination_directory, exist_ok=True)

    # Get all .nc files in the source directory
    filenames = [os.path.join(source_directory, f) for f in os.listdir(source_directory) if f.endswith('.nc')]

    # Use ProcessPoolExecutor to process files in parallel
    with ProcessPoolExecutor(max_workers=os.cpu_count()) as executor:
        # Map the processing function to each file
        results = executor.map(mask_file, filenames, [destination_directory]*len(filenames))

        # Optionally collect results or handle exceptions
        for result in results:
            print(result)

# %% [markdown]
# ## Time Series

# %% [markdown]
# ### *calculate_flow_for_n_days*
# Crashes when n is big.

# %%
def calculate_flow_for_n_days(source_directory, output_path, days=10):
    """
    Calculates and concatenates flow data for a specified number of days.

    Parameters:
    - source_directory (str): Directory containing NetCDF files to process.
    - output_path (str): Path to save the combined NetCDF file.
    - days (int): Number of days to process. This translates to (days-1) pairs of files.
    """
    # Get all .nc files sorted to ensure chronological order
    files = sorted([os.path.join(source_directory, f) for f in os.listdir(source_directory) if f.endswith('.nc')])
    
    # Limit to the specified number of days, ensuring there are pairs to process
    files = files[:days] if len(files) >= days else files

    # Prepare to store datasets
    datasets = []
    
    # Process each pair of files
    for i in range(len(files) - 1):
        first_path = files[i]
        second_path = files[i+1]
        
        # Calculate flow vectors
        flow_u, flow_v = calculate_deepflow(first_path, second_path, variable_key="fai_anomaly")
        
        # Load the first file as base for coordinates and other metadata
        ds = xr.open_dataset(first_path, chunks={"latitude": "auto", "longitude": "auto"})
        ds['flow_u'] = (('latitude', 'longitude'), flow_u)
        ds['flow_v'] = (('latitude', 'longitude'), flow_v)
        
        # Extract date from filename and handle possible errors
        try:
            date_str = os.path.basename(first_path).split('_')[3].split('.')[0]
            date = datetime.strptime(date_str, '%Y%m%d')
            ds = ds.assign_coords(time=date)
            ds = ds.expand_dims('time')
        except Exception as e:
            print(f"Failed to parse dates from filenames {first_path}: {e}")
            continue

        datasets.append(ds)
    
    # Concatenate all datasets along time dimension
    if datasets:
        combined_dataset = xr.concat(datasets, dim='time')
        combined_dataset.to_netcdf(output_path)
        print(f"Flow data for {days-1} days saved to {output_path}")
    else:
        print("No datasets to combine or an error occurred.")

# %%
if __name__ == '__main__':
    source_directory = '/media/yahia/ballena/ABI/NetCDF/Atlantic/Filtered'
    output_path = '/media/yahia/ballena/Flow/Custom_Days_Flow.nc'
    days = 3
    calculate_flow_for_n_days(source_directory, output_path, days=days)
# Out:
# Flow data for 2 days saved to /media/yahia/ballena/Flow/Custom_Days_Flow.nc
