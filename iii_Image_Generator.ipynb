# %% [markdown]
# # Image Generator
# This notebook was created to ease the image generation process, i.e turning the netCDF data into something the OF algorithms can take as input and saving it to the hard drive.
#
# **N.B: The functions used here do not create the directories, they have to be created manually. (NO LONGER)**

# %% [markdown]
# ## Importing necessary libraries and notebooks

# %%
import xarray as xr
import os
import cv2
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import time
from datetime import datetime, timedelta
from matplotlib import ticker
from IPython.display import Image, display, HTML
from concurrent.futures import ProcessPoolExecutor

# Import the other notebooks without running their cells
from i_GOES_average import time_list, visualize_aggregate, calculate_median
from ii_Image_Processing import *

# %% [markdown]
# ## Atlantic

# %%
# Global Atlantic (without partition)
if __name__ == '__main__':
    start_date = '20221207'
    end_date = '20221231'
    directory = '/media/yahia/ballena/CLS/abi-goes-global-hr' 
    output_directory = '/media/yahia/ballena/ABI/NetCDF/Atlantic/Averages' 
    
    # Calculate the 1-day averages and save them
    process_dates(start_date, end_date, directory, output_directory, color="viridis", save_image=False, save_netcdf=True)
# Out:
# Processed and saved data for 20221207
# Skipping: /media/yahia/ballena/CLS/abi-goes-global-hr/cls-abi-goes-global-hr_1d_20221208_12-30.nc does not exist.
# Skipping: /media/yahia/ballena/CLS/abi-goes-global-hr/cls-abi-goes-global-hr_1d_20221208_12-40.nc does not exist.
# Skipping: /media/yahia/ballena/CLS/abi-goes-global-hr/cls-abi-goes-global-hr_1d_20221208_12-50.nc does not exist.
# Skipping: /media/yahia/ballena/CLS/abi-goes-global-hr/cls-abi-goes-global-hr_1d_20221208_13-00.nc does not exist.
# Skipping: /media/yahia/ballena/CLS/abi-goes-global-hr/cls-abi-goes-global-hr_1d_20221208_13-10.nc does not exist.
# Skipping: /media/yahia/ballena/CLS/abi-goes-global-hr/cls-abi-goes-global-hr_1d_20221208_13-20.nc does not exist.
# Processed and saved data for 20221208
# Processed and saved data for 20221209
# Processed and saved data for 20221210
# Processed and saved data for 20221211
# Processed and saved data for 20221212
# Processed and saved data for 20221213
# Processed and saved data for 20221214
# Processed and saved data for 20221215
# Processed and saved data for 20221216
# Processed and saved data for 20221217
# Processed and saved data for 20221218
# Processed and saved data for 20221219
# Processed and saved data for 20221220
# Skipping: /media/yahia/ballena/CLS/abi-goes-global-hr/cls-abi-goes-global-hr_1d_20221221_14-40.nc does not exist.
# Skipping: /media/yahia/ballena/CLS/abi-goes-global-hr/cls-abi-goes-global-hr_1d_20221221_14-50.nc does not exist.
# Skipping: /media/yahia/ballena/CLS/abi-goes-global-hr/cls-abi-goes-global-hr_1d_20221221_15-00.nc does not exist.
# Processed and saved data for 20221221
# Processed and saved data for 20221222
# Processed and saved data for 20221223
# Processed and saved data for 20221224
# Processed and saved data for 20221225
# Processed and saved data for 20221226
# Processed and saved data for 20221227
# Processed and saved data for 20221228
# Processed and saved data for 20221229
# Processed and saved data for 20221230
# Processed and saved data for 20221231

# %% [markdown]
# File size: 98 Mb

# %% [markdown]
# ## Filtered Atlantic
# This produces a netcdf with an unfiltered and filtered version.

# %% [markdown]
# #### *process_file*
# Process the NetCDF file (binarizing the averages for first variable and filtering them for second variable)

# %%
def process_file(filename, source_directory, destination_directory):
    """
    Process a single NetCDF file and save the processed result.
    """
    source_path = os.path.join(source_directory, filename)
    new_filename = 'Filtered_' + filename
    dest_path = os.path.join(destination_directory, new_filename)
    
    # Process the NetCDF file (binarizing the averages for first variable and filtering them for second variable)
    fai_anomaly_result = process_netCDF(source_path, threshold=1, binarize=True, 
                                         filter_small=False, land_mask=False, coast_mask=False)
    
    filtered_result = process_netCDF(source_path, threshold=1, binarize=True,  
                                      filter_small=False, size_threshold=10, land_mask=True, coast_mask=True, 
                                      coast_threshold=50000, adaptive_small=True, base_threshold=15, higher_threshold=10000, 
                                      latitude_limit=30)
    
    # Convert DataArray to Dataset if needed
    if isinstance(fai_anomaly_result, xr.DataArray):
        fai_anomaly_result = fai_anomaly_result.to_dataset(name='fai_anomaly')
    if isinstance(filtered_result, xr.DataArray):
        filtered_result = filtered_result.to_dataset(name='filtered')

    # Merge datasets
    combined_dataset = xr.merge([fai_anomaly_result, filtered_result])

    # Save the combined dataset
    combined_dataset.to_netcdf(dest_path)
    
    # Print success message
    print(f"Successfully processed and saved: {new_filename}")

# %%
## Sequential

# if __name__ == '__main__':
#     # Paths
#     source_directory = '/media/yahia/ballena/ABI/NetCDF/Atlantic/Averages' 
#     destination_directory = '/media/yahia/ballena/ABI/NetCDF/Atlantic/Filtered' 
    
#     # Process the directory (binarize the images)
#     # Iterate over all files in the source directory
#     for filename in os.listdir(source_directory):
#         if filename.endswith('.nc'):
#             # Original NetCDF file path
#             source_path = os.path.join(source_directory, filename)
            
#             # New filename with 'Processed' prefix
#             new_filename = 'Filtered_' + filename
            
#             # Define the output path for the processed NetCDF file
#             dest_path = os.path.join(destination_directory, new_filename)
            
#             # Process the NetCDF file
#             # First dimension
#             fai_anomaly_dataset = process_netCDF(source_path, threshold=1, bilateral=False, binarize=True, crop=False, negative=False, 
#                                   filter_small=False, land_mask=False, coast_mask=False)

#             # Second dimension
#             masked_land = process_netCDF(source_path, threshold=1, bilateral=False, binarize=True, crop=False, negative=False, 
#                                   filter_small=False, land_mask=True, coast_mask=False)
            
#             # Third dimension
#             filtered_dataset = process_netCDF(source_path, threshold=1, bilateral=False, binarize=True, crop=False, negative=False, 
#                                filter_small=True, size_threshold=10, land_mask=True, coast_mask=True, coast_threshold=50000)
        
#             # Extract the main variable from each dataset
#             fai_anomaly_data = fai_anomaly_dataset[list(fai_anomaly_dataset.data_vars)[0]]
#             masked_land = masked_land[list(masked_land.data_vars)[0]]
#             filtered_data = filtered_dataset[list(filtered_dataset.data_vars)[0]]
            
#             # Combine both datasets into a new dataset with both variables
#             combined_dataset = xr.Dataset({
#                 'fai_anomaly': fai_anomaly_data,
#                 'masked_land': masked_land,
#                 'filtered': filtered_data
#             })

#             # Saving the file
#             combined_dataset.to_netcdf(dest_path)

# %%
# Parallel
if __name__ == "__main__":
    source_directory = '/media/yahia/ballena/ABI/NetCDF/Atlantic/Averages'
    destination_directory = '/media/yahia/ballena/ABI/NetCDF/Atlantic/Filtered'
    
    # Get all .nc files in the source directory
    filenames = [f for f in os.listdir(source_directory) if f.endswith('.nc')]
    
    # Use ProcessPoolExecutor to process files in parallel
    with ProcessPoolExecutor(max_workers=8) as executor:
        # Map the processing function to each file
        futures = [executor.submit(process_file, filename, source_directory, destination_directory) for filename in filenames]
        
        # Optionally collect results or handle exceptions
        for future in futures:
            try:
                result = future.result()  # Wait for each future to complete if needed
            except Exception as e:
                print(f"Error processing file: {str(e)}")
# Out:
# Successfully processed and saved: Filtered_algae_distribution_20220724.nc
# Successfully processed and saved: Filtered_algae_distribution_20220706.nc
# Successfully processed and saved: Filtered_algae_distribution_20220705.nc
# Successfully processed and saved: Filtered_algae_distribution_20220701.nc
# Successfully processed and saved: Filtered_algae_distribution_20220723.nc
# Successfully processed and saved: Filtered_algae_distribution_20220702.nc
# Successfully processed and saved: Filtered_algae_distribution_20220710.nc
# Successfully processed and saved: Filtered_algae_distribution_20220707.nc
# Successfully processed and saved: Filtered_algae_distribution_20220714.nc
# Successfully processed and saved: Filtered_algae_distribution_20220716.nc
# Successfully processed and saved: Filtered_algae_distribution_20220708.nc
# Successfully processed and saved: Filtered_algae_distribution_20220703.nc
# Successfully processed and saved: Filtered_algae_distribution_20220719.nc
# Successfully processed and saved: Filtered_algae_distribution_20220720.nc
# Successfully processed and saved: Filtered_algae_distribution_20220721.nc
# Successfully processed and saved: Filtered_algae_distribution_20220713.nc
# Successfully processed and saved: Filtered_algae_distribution_20220704.nc
# Successfully processed and saved: Filtered_algae_distribution_20220726.nc
# Successfully processed and saved: Filtered_algae_distribution_20220725.nc
# Successfully processed and saved: Filtered_algae_distribution_20220709.nc
# Successfully processed and saved: Filtered_algae_distribution_20220718.nc
# Successfully processed and saved: Filtered_algae_distribution_20220727.nc
# Successfully processed and saved: Filtered_algae_distribution_20220728.nc
# Successfully processed and saved: Filtered_algae_distribution_20220730.nc
# Successfully processed and saved: Filtered_algae_distribution_20220502.nc
# Successfully processed and saved: Filtered_algae_distribution_20220731.nc
# Successfully processed and saved: Filtered_algae_distribution_20220503.nc
# Successfully processed and saved: Filtered_algae_distribution_20220505.nc
# Successfully processed and saved: Filtered_algae_distribution_20220729.nc
# Successfully processed and saved: Filtered_algae_distribution_20220712.nc
# Successfully processed and saved: Filtered_algae_distribution_20220507.nc
# Successfully processed and saved: Filtered_algae_distribution_20220501.nc
# Successfully processed and saved: Filtered_algae_distribution_20220506.nc
# Successfully processed and saved: Filtered_algae_distribution_20220717.nc
# Successfully processed and saved: Filtered_algae_distribution_20220508.nc
# Successfully processed and saved: Filtered_algae_distribution_20220510.nc
# Successfully processed and saved: Filtered_algae_distribution_20220512.nc
# Successfully processed and saved: Filtered_algae_distribution_20220511.nc
# Successfully processed and saved: Filtered_algae_distribution_20220722.nc
# Successfully processed and saved: Filtered_algae_distribution_20220513.nc
# Successfully processed and saved: Filtered_algae_distribution_20220515.nc
# Successfully processed and saved: Filtered_algae_distribution_20220509.nc
# Successfully processed and saved: Filtered_algae_distribution_20220518.nc
# Successfully processed and saved: Filtered_algae_distribution_20220504.nc
# Successfully processed and saved: Filtered_algae_distribution_20220522.nc
# Successfully processed and saved: Filtered_algae_distribution_20220523.nc
# Successfully processed and saved: Filtered_algae_distribution_20220517.nc
# Successfully processed and saved: Filtered_algae_distribution_20220521.nc
# Successfully processed and saved: Filtered_algae_distribution_20220516.nc
# Successfully processed and saved: Filtered_algae_distribution_20220525.nc
# Successfully processed and saved: Filtered_algae_distribution_20220526.nc
# Successfully processed and saved: Filtered_algae_distribution_20220528.nc
# Successfully processed and saved: Filtered_algae_distribution_20220519.nc
# Successfully processed and saved: Filtered_algae_distribution_20220524.nc
# Successfully processed and saved: Filtered_algae_distribution_20220520.nc
# Successfully processed and saved: Filtered_algae_distribution_20220530.nc
# Successfully processed and saved: Filtered_algae_distribution_20220602.nc
# Successfully processed and saved: Filtered_algae_distribution_20220601.nc
# Successfully processed and saved: Filtered_algae_distribution_20220606.nc
# Successfully processed and saved: Filtered_algae_distribution_20220607.nc
# Successfully processed and saved: Filtered_algae_distribution_20220605.nc
# Successfully processed and saved: Filtered_algae_distribution_20220608.nc
# Successfully processed and saved: Filtered_algae_distribution_20220527.nc
# Successfully processed and saved: Filtered_algae_distribution_20220604.nc
# Successfully processed and saved: Filtered_algae_distribution_20220529.nc
# Successfully processed and saved: Filtered_algae_distribution_20220603.nc
# Successfully processed and saved: Filtered_algae_distribution_20220609.nc
# Successfully processed and saved: Filtered_algae_distribution_20220615.nc
# Successfully processed and saved: Filtered_algae_distribution_20220612.nc
# Successfully processed and saved: Filtered_algae_distribution_20220620.nc
# Successfully processed and saved: Filtered_algae_distribution_20220611.nc
# Successfully processed and saved: Filtered_algae_distribution_20220613.nc
# Successfully processed and saved: Filtered_algae_distribution_20220622.nc
# Successfully processed and saved: Filtered_algae_distribution_20220624.nc
# Successfully processed and saved: Filtered_algae_distribution_20220616.nc
# Successfully processed and saved: Filtered_algae_distribution_20220610.nc
# Successfully processed and saved: Filtered_algae_distribution_20220619.nc
# Successfully processed and saved: Filtered_algae_distribution_20220623.nc
# Successfully processed and saved: Filtered_algae_distribution_20220625.nc
# Successfully processed and saved: Filtered_algae_distribution_20220614.nc
# Successfully processed and saved: Filtered_algae_distribution_20220630.nc
# Successfully processed and saved: Filtered_algae_distribution_20220626.nc
# Successfully processed and saved: Filtered_algae_distribution_20220802.nc
# Successfully processed and saved: Filtered_algae_distribution_20220627.nc
# Successfully processed and saved: Filtered_algae_distribution_20220629.nc
# Successfully processed and saved: Filtered_algae_distribution_20220628.nc
# Successfully processed and saved: Filtered_algae_distribution_20220621.nc
# Successfully processed and saved: Filtered_algae_distribution_20220801.nc
# Successfully processed and saved: Filtered_algae_distribution_20220803.nc
# Successfully processed and saved: Filtered_algae_distribution_20220804.nc
# Successfully processed and saved: Filtered_algae_distribution_20220807.nc
# Successfully processed and saved: Filtered_algae_distribution_20220817.nc
# Successfully processed and saved: Filtered_algae_distribution_20220810.nc
# Successfully processed and saved: Filtered_algae_distribution_20220819.nc
# Successfully processed and saved: Filtered_algae_distribution_20220820.nc
# Successfully processed and saved: Filtered_algae_distribution_20220821.nc
# Successfully processed and saved: Filtered_algae_distribution_20220808.nc
# Successfully processed and saved: Filtered_algae_distribution_20220822.nc
# Successfully processed and saved: Filtered_algae_distribution_20220818.nc
# Successfully processed and saved: Filtered_algae_distribution_20220825.nc
# Successfully processed and saved: Filtered_algae_distribution_20220823.nc
# Successfully processed and saved: Filtered_algae_distribution_20220809.nc
# Successfully processed and saved: Filtered_algae_distribution_20220828.nc
# Successfully processed and saved: Filtered_algae_distribution_20220826.nc
# Successfully processed and saved: Filtered_algae_distribution_20220831.nc
# Successfully processed and saved: Filtered_algae_distribution_20220806.nc
# Successfully processed and saved: Filtered_algae_distribution_20220827.nc
# Successfully processed and saved: Filtered_algae_distribution_20220902.nc
# Successfully processed and saved: Filtered_algae_distribution_20220903.nc
# Successfully processed and saved: Filtered_algae_distribution_20220904.nc
# Successfully processed and saved: Filtered_algae_distribution_20220805.nc
# Successfully processed and saved: Filtered_algae_distribution_20220906.nc
# Successfully processed and saved: Filtered_algae_distribution_20220908.nc
# Successfully processed and saved: Filtered_algae_distribution_20220907.nc
# Successfully processed and saved: Filtered_algae_distribution_20220905.nc
# Successfully processed and saved: Filtered_algae_distribution_20220913.nc
# Successfully processed and saved: Filtered_algae_distribution_20220830.nc
# Successfully processed and saved: Filtered_algae_distribution_20220910.nc
# Successfully processed and saved: Filtered_algae_distribution_20220914.nc
# Successfully processed and saved: Filtered_algae_distribution_20220912.nc
# Successfully processed and saved: Filtered_algae_distribution_20220824.nc
# Successfully processed and saved: Filtered_algae_distribution_20220918.nc
# Successfully processed and saved: Filtered_algae_distribution_20220917.nc
# Successfully processed and saved: Filtered_algae_distribution_20220829.nc
# Successfully processed and saved: Filtered_algae_distribution_20220920.nc
# Successfully processed and saved: Filtered_algae_distribution_20220915.nc
# Successfully processed and saved: Filtered_algae_distribution_20220916.nc
# Successfully processed and saved: Filtered_algae_distribution_20220922.nc
# Successfully processed and saved: Filtered_algae_distribution_20220919.nc
# Successfully processed and saved: Filtered_algae_distribution_20220923.nc
# Successfully processed and saved: Filtered_algae_distribution_20220924.nc
# Successfully processed and saved: Filtered_algae_distribution_20220901.nc
# Successfully processed and saved: Filtered_algae_distribution_20220927.nc
# Successfully processed and saved: Filtered_algae_distribution_20220930.nc
# Successfully processed and saved: Filtered_algae_distribution_20220926.nc
# Successfully processed and saved: Filtered_algae_distribution_20220928.nc
# Successfully processed and saved: Filtered_algae_distribution_20220921.nc
# Successfully processed and saved: Filtered_algae_distribution_20221003.nc
# Successfully processed and saved: Filtered_algae_distribution_20220925.nc
# Successfully processed and saved: Filtered_algae_distribution_20221001.nc
# Successfully processed and saved: Filtered_algae_distribution_20221005.nc
# Successfully processed and saved: Filtered_algae_distribution_20220909.nc
# Successfully processed and saved: Filtered_algae_distribution_20221007.nc
# Successfully processed and saved: Filtered_algae_distribution_20221009.nc
# Successfully processed and saved: Filtered_algae_distribution_20221011.nc
# Successfully processed and saved: Filtered_algae_distribution_20221012.nc
# Successfully processed and saved: Filtered_algae_distribution_20221013.nc
# Successfully processed and saved: Filtered_algae_distribution_20221010.nc
# Successfully processed and saved: Filtered_algae_distribution_20221015.nc
# Successfully processed and saved: Filtered_algae_distribution_20221004.nc
# Successfully processed and saved: Filtered_algae_distribution_20221017.nc
# Successfully processed and saved: Filtered_algae_distribution_20221018.nc
# Successfully processed and saved: Filtered_algae_distribution_20221002.nc
# Successfully processed and saved: Filtered_algae_distribution_20221016.nc
# Successfully processed and saved: Filtered_algae_distribution_20221008.nc
# Successfully processed and saved: Filtered_algae_distribution_20221020.nc
# Successfully processed and saved: Filtered_algae_distribution_20221021.nc
# Successfully processed and saved: Filtered_algae_distribution_20221023.nc
# Successfully processed and saved: Filtered_algae_distribution_20221019.nc
# Successfully processed and saved: Filtered_algae_distribution_20221026.nc
# Successfully processed and saved: Filtered_algae_distribution_20221029.nc
# Successfully processed and saved: Filtered_algae_distribution_20221025.nc
# Successfully processed and saved: Filtered_algae_distribution_20221024.nc
# Successfully processed and saved: Filtered_algae_distribution_20221028.nc
# Successfully processed and saved: Filtered_algae_distribution_20221031.nc
# Successfully processed and saved: Filtered_algae_distribution_20221030.nc
# Successfully processed and saved: Filtered_algae_distribution_20221101.nc
# Successfully processed and saved: Filtered_algae_distribution_20221022.nc
# Successfully processed and saved: Filtered_algae_distribution_20221105.nc
# Successfully processed and saved: Filtered_algae_distribution_20221106.nc
# Successfully processed and saved: Filtered_algae_distribution_20221104.nc
# Successfully processed and saved: Filtered_algae_distribution_20221109.nc
# Successfully processed and saved: Filtered_algae_distribution_20221014.nc
# Successfully processed and saved: Filtered_algae_distribution_20221110.nc
# Successfully processed and saved: Filtered_algae_distribution_20221111.nc
# Successfully processed and saved: Filtered_algae_distribution_20221103.nc
# Successfully processed and saved: Filtered_algae_distribution_20221112.nc
# Successfully processed and saved: Filtered_algae_distribution_20221115.nc
# Successfully processed and saved: Filtered_algae_distribution_20221113.nc
# Successfully processed and saved: Filtered_algae_distribution_20221116.nc
# Successfully processed and saved: Filtered_algae_distribution_20221117.nc
# Successfully processed and saved: Filtered_algae_distribution_20221119.nc
# Successfully processed and saved: Filtered_algae_distribution_20221108.nc
# Successfully processed and saved: Filtered_algae_distribution_20221122.nc
# Successfully processed and saved: Filtered_algae_distribution_20221107.nc
# Successfully processed and saved: Filtered_algae_distribution_20221006.nc
# Successfully processed and saved: Filtered_algae_distribution_20221118.nc
# Successfully processed and saved: Filtered_algae_distribution_20221125.nc
# Successfully processed and saved: Filtered_algae_distribution_20221126.nc
# Successfully processed and saved: Filtered_algae_distribution_20221123.nc
# Successfully processed and saved: Filtered_algae_distribution_20221127.nc
# Successfully processed and saved: Filtered_algae_distribution_20221114.nc
# Successfully processed and saved: Filtered_algae_distribution_20221202.nc
# Successfully processed and saved: Filtered_algae_distribution_20221130.nc
# Successfully processed and saved: Filtered_algae_distribution_20221201.nc
# Successfully processed and saved: Filtered_algae_distribution_20221027.nc
# Successfully processed and saved: Filtered_algae_distribution_20221203.nc
# Successfully processed and saved: Filtered_algae_distribution_20221129.nc
# Successfully processed and saved: Filtered_algae_distribution_20221209.nc
# Successfully processed and saved: Filtered_algae_distribution_20221124.nc
# Successfully processed and saved: Filtered_algae_distribution_20221204.nc
# Successfully processed and saved: Filtered_algae_distribution_20221212.nc
# Successfully processed and saved: Filtered_algae_distribution_20221210.nc
# Successfully processed and saved: Filtered_algae_distribution_20221128.nc
# Successfully processed and saved: Filtered_algae_distribution_20221208.nc
# Successfully processed and saved: Filtered_algae_distribution_20221121.nc
# Successfully processed and saved: Filtered_algae_distribution_20221207.nc
# Successfully processed and saved: Filtered_algae_distribution_20221213.nc
# Successfully processed and saved: Filtered_algae_distribution_20221220.nc
# Successfully processed and saved: Filtered_algae_distribution_20221214.nc
# Successfully processed and saved: Filtered_algae_distribution_20221217.nc
# Successfully processed and saved: Filtered_algae_distribution_20221215.nc
# Successfully processed and saved: Filtered_algae_distribution_20221218.nc
# Successfully processed and saved: Filtered_algae_distribution_20221216.nc
# Successfully processed and saved: Filtered_algae_distribution_20221219.nc
# Successfully processed and saved: Filtered_algae_distribution_20221223.nc
# Successfully processed and saved: Filtered_algae_distribution_20221211.nc
# Successfully processed and saved: Filtered_algae_distribution_20221221.nc
# Successfully processed and saved: Filtered_algae_distribution_20221224.nc
# Successfully processed and saved: Filtered_algae_distribution_20221222.nc
# Successfully processed and saved: Filtered_algae_distribution_20221225.nc
# Successfully processed and saved: Filtered_algae_distribution_20221226.nc
# Successfully processed and saved: Filtered_algae_distribution_20221227.nc
# Successfully processed and saved: Filtered_algae_distribution_20221229.nc
# Successfully processed and saved: Filtered_algae_distribution_20221228.nc
# Successfully processed and saved: Filtered_algae_distribution_20221230.nc
# Successfully processed and saved: Filtered_algae_distribution_20221231.nc
